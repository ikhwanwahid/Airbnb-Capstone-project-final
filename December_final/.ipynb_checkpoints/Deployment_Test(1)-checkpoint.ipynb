# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import nltk
import string
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from tqdm import tqdm

# %%
finaldf=pd.read_csv('./finaldf.csv')
listings=pd.read_csv('./')

# %%
finaldf.head()
# Out:
#    index  listing_id    id        date  reviewer_id reviewer_name  \
# 0      0        2515   198  2008-10-13         2603         Jenny
# 1      1        2515   859  2009-03-08         8455        Roland
# 2      2        2515  1083  2009-03-25         9759           Cem
# 3      3        2515  1107  2009-03-27         9193         Holly
# 4      4        2515  2175  2009-05-09         7048    Alessandra
#
#    Dominant_Topic  Topic_Perc_Contrib  \
# 0             4.0              0.6866
# 1             2.0              0.4246
# 2             2.0              0.4472
# 3             2.0              0.5302
# 4             4.0              0.4902
#
#                                             Keywords  \
# 0  great, place, stay, location, host, clean, rec...
# 1  stay, place, make, feel, home, time, thank, ba...
# 2  stay, place, make, feel, home, time, thank, ba...
# 3  stay, place, make, feel, home, time, thank, ba...
# 4  great, place, stay, location, host, clean, rec...
#
#                                                 Text  sentiment_score
# 0  Stephanie was a wonderful host! Her apartment ...           0.9357
# 1  Such a wonderful place and very close to the m...           0.9727
# 2  I just got back from a trip to NYC during whic...           0.9620
# 3  Stephanie's offered all the most important thi...           0.9626
# 4  Stephanie was really nice, ftiendly and helpfu...           0.9335

# %%
finaldf[finaldf['sentiment_score']<0]
# Out:
#          index  listing_id         id        date  reviewer_id reviewer_name  \
# 26          26        2515      77637  2010-08-13       183527        Yutaro
# 56          56        2515     760569  2011-12-03      1358563     Katherine
# 79          79        2515    5613012  2013-07-08      6837286         Arjun
# 173        173        2515  350116678  2018-11-18    162106712      Federico
# 241        241        5216      18436  2009-11-27        51224         Paula
# ...        ...         ...        ...         ...          ...           ...
# 346666  346849    30856884  364900950  2018-12-31    105123350         Corey
# 346703  346886    30901275  362487143  2018-12-26    218963950         Nicky
# 346739  346922    30926919  362116807  2018-12-25    130241163           Ira
# 346779  346962    30940476  367311167  2019-01-04      3143497      Marquett
# 346867  347050    31055440  365585063  2019-01-01    121880623       Mariana
#
#         Dominant_Topic  Topic_Perc_Contrib  \
# 26                 1.0              0.7988
# 56                 0.0              0.4659
# 79                 2.0              0.3832
# 173                0.0              0.4503
# 241                1.0              0.7265
# ...                ...                 ...
# 346666             1.0              0.7861
# 346703             3.0              0.7043
# 346739             1.0              0.6071
# 346779             1.0              0.9269
# 346867             1.0              0.5920
#
#                                                  Keywords  \
# 26      host, day, night, arrival, check, apartment, g...
# 56      close, walk, subway, apartment, restaurant, gr...
# 79      stay, place, make, feel, home, time, thank, ba...
# 173     close, walk, subway, apartment, restaurant, gr...
# 241     host, day, night, arrival, check, apartment, g...
# ...                                                   ...
# 346666  host, day, night, arrival, check, apartment, g...
# 346703  room, good, clean, bed, apartment, bathroom, n...
# 346739  host, day, night, arrival, check, apartment, g...
# 346779  host, day, night, arrival, check, apartment, g...
# 346867  host, day, night, arrival, check, apartment, g...
#
#                                                      Text  sentiment_score
# 26                      The host cancelled my reservation          -0.2500
# 56      Stephanie made us feel right at home! The week...          -0.4199
# 79      It was a decent location. People who want to v...          -0.2280
# 173     The accommodation exceeded my expectations by ...          -0.2023
# 241     Our stay was disappointing as we did not stay ...          -0.9570
# ...                                                   ...              ...
# 346666  Find a different room I’m not one to normally ...          -0.1901
# 346703  Details was missing from advertising where the...          -0.0258
# 346739  The apartment is near the subway station, whic...          -0.7003
# 346779  Internet was off and not working when we arriv...          -0.5267
# 346867  The department is a local street now used to r...          -0.9905
#
# [8996 rows x 11 columns]
